# %% [markdown]
# #### This is a demonstration of the code usage for implementing asynchronous networks algorithm.

# %%
# Ordinary asynchronous network

import matplotlib.pyplot as plt

from Neuron import Neuron
from calculate import calculate
from ECS import ECS
from save_data import save_data, load_data
from plots import show_plot

neurons, ecs, iterations = load_data('saved_params/Lymnaea triphasic.csv')
params = calculate(neurons, ecs, iterations)
show_plot(params)
plt.show()

# %%
# Asynchronous network with variable receptor weight and transmitter release (neuromodulation)

import matplotlib.pyplot as plt

from Neuron_modul import Neuron
from calculate_modul import calculate
from ECS import ECS
from save_data_modul import save_data, load_data
from plots import show_plot

neurons, ecs, iterations = load_data('saved_params/test.csv')
params = calculate(neurons, ecs, iterations)
show_plot(params)
plt.show()

# %% [markdown]
# tonic 2 increases the activation effect of tonic 1 on oscillator (modulation)
